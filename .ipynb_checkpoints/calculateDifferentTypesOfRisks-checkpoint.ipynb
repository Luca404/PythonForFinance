# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
#Procter&Gamble and Ford 
tickers = ['PG','F']
data = pd.DataFrame()
for ticker in tickers:
    data[ticker] = wb.DataReader(ticker, data_source="yahoo", start='2005-1-1')['Adj Close']
