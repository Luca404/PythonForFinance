# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
#Procter&Gamble, Microsoft, Ford and General Electric
tickers = ['PG', 'MSFT', 'F', 'GE']
data = pd.DataFrame()
for ticker in tickers:
    data[ticker] = wb.DataReader(ticker, data_source="yahoo", start='2005-1-1')['Adj Close']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4391 entries, 2005-01-03 to 2022-06-10
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PG      4391 non-null   float64
#  1   MSFT    4391 non-null   float64
#  2   F       4391 non-null   float64
#  3   GE      4391 non-null   float64
# dtypes: float64(4)
# memory usage: 171.5 KB

# %%
data.head()
# Out:
#                    PG       MSFT         F          GE
# Date
# 2005-01-03  33.773102  18.954119  9.117530  172.045288
# 2005-01-04  33.350838  19.025009  9.086539  169.976517
# 2005-01-05  33.699661  18.982475  8.943979  168.941971
# 2005-01-06  33.864883  18.961205  8.956375  170.305557
# 2005-01-07  34.219807  18.904512  9.080339  169.271164

# %%
(data / data.iloc[0] * 100).plot(figsize = (15, 6))
plt.show()

# %%
returns = ((data / data.shift(1))-1).mean() * 250

# %%
returns
# Out:
# PG      0.098318
# MSFT    0.184489
# F       0.108403
# GE      0.005488
# dtype: float64

# %%
weights = np.array([0.25, 0.25, 0.25, 0.25])

# %%
np.dot(returns, weights)*100
# Out:
# 9.917423397887202
